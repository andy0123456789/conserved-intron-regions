# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from glob import glob
sns.set_style("white")

# %%
region1 = pd.read_table("bigwig_intronic/huandy_24281_chrY_9175337_9175355",names=["chromosome","start","end","conservation"])
region2 = pd.read_table("bigwig_intronic/huandy_24281_chrY_9175622_9176229",names=["chromosome","start","end","conservation"])
region4 = pd.read_table("bigwig_intronic/huandy_24281_chrY_9176307_9176435",names=["chromosome","start","end","conservation"])

# %%
files = glob("data/bigwig_intronic/huandy_24281_chr10_1000*")

# %%
for f in files:
    region = pd.read_table(f,names=["chromosome","start","end","conservation"])
    plt.step(region["start"],region["conservation"])
    plt.show()

# %%
plt.step(region1["start"],region1["conservation"])
plt.show()
plt.step(region2["start"],region2["conservation"])
plt.show()
plt.step(region4["start"],region4["conservation"])
plt.show()
plt.step(region["start"],region["conservation"])
plt.show()
